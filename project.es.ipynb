# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')

print(ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

casa_mas_cara=ds["price"].idxmax()
direccion_casa_mas_cara=ds.loc[casa_mas_cara,"address"]
precio_casa_mas_cara=ds.loc[casa_mas_cara,"price"]
print("La casa con dirección en calle",direccion_casa_mas_cara,",","es la más cara y su precio es de",precio_casa_mas_cara,"USD")
# Out:
# La casa con dirección en calle El Escorial , es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

casa_mas_barata=ds["price"].idxmin()
direccion_casa_mas_barata=ds.loc[casa_mas_barata,"address"]
precio_casa_mas_barata=ds.loc[casa_mas_barata,"price"]
print("La casa con dirección en Calle",direccion_casa_mas_barata,",","es la más barata y su precio es de",precio_casa_mas_barata,"USD")
# Out:
# La casa con dirección en Calle Parla , es la más barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

casa_mas_grande=ds["surface"].idxmax()
direccion_casa_mas_grande=ds.loc[casa_mas_grande,"address"]
superficie_casa_mas_grande=ds.loc[casa_mas_grande,"surface"]

print("La casa más grande está ubicada en la Calle",direccion_casa_mas_grande,", y su superficie es de",superficie_casa_mas_grande,"metros")

casa_mas_pequeña=ds["surface"].idxmin()
direccion_casa_mas_pequeña=ds.loc[casa_mas_pequeña,"address"]
superficie_casa_mas_pequeña=ds.loc[casa_mas_pequeña,"surface"]

print("La casa más pequeña está ubicada en Calle",direccion_casa_mas_pequeña,", y su superficie es de",superficie_casa_mas_pequeña,"metros")
# Out:
# La casa más grande está ubicada en la Calle Sevilla la Nueva , y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Calle Amparo,  Madrid Capital , y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones=ds["level5"].dropna().unique()

print(",".join(poblaciones))
# Out:
# Arganda del Rey,Fuenlabrada,Boadilla del Monte,Las Rozas de Madrid, Madrid Capital,Villaviciosa de Odón,Pinto,Valdemoro,Navalcarnero,Pozuelo de Alarcón,Torrejón de Ardoz,Navalagamella,San Sebastián de los Reyes,Rivas-vaciamadrid,Alpedrete,Móstoles,San Fernando de Henares,Coslada,Becerril de la Sierra,Alcalá de Henares,Chinchón,Parla,Alcorcón,El Escorial,Leganés,Pedrezuela,Majadahonda,Villanueva de la Cañada,Villanueva del Pardillo,Torrelodones,Moralzarzal,Mejorada del Campo,Aranjuez,Corpa,Getafe,Velilla de San Antonio,Sevilla la Nueva,San Martín de la Vega,Villalbilla,Collado Villalba,Alcobendas,El Molar (Madrid),Moraleja de Enmedio,Algete,Campo Real,Torrejón de la Calzada,Colmenar Viejo,Valdemorillo,Fuente El Saz de Jarama,Tres Cantos,Arroyomolinos (Madrid),Griñón,Paracuellos de Jarama,Guadarrama,Titulcia,Galapagar,Collado Mediano,Los Molinos,San Lorenzo de El Escorial,Loeches,San Martín de Valdeiglesias,Navas del Rey,Bustarviejo,Manzanares El Real,Carabaña,Casarrubuelos,Cercedilla,
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

contiene_NAs=ds.isna().any()

print(contiene_NAs)
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

print("DataFrame Original:")
print(ds.shape)

columnas_ignoradas=["Unnamed: 0","id_realEstates","isNew","url_inmueble","price","date","address","country","level1","level2","level3","level5","upperLevel","countryId","level1Id","level2Id","level3Id","level4Id","level5Id","level6Id","level7Id","level8Id","accuracy","latitude","longitude"]
columnas_relevantes=[col for col in ds.columns if col not in columnas_ignoradas]
ds_eliminando_NAs=ds.dropna(subset=columnas_relevantes)

print("DataFrame después de las eliminaciones:",)
print(ds_eliminando_NAs.shape)
# Out:
# DataFrame Original:
# (15335, 37)
# DataFrame después de las eliminaciones:
# (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

media_precios_Arroyomolinos_Madrid=ds[ds["level5"]=="Arroyomolinos (Madrid)"]["price"].mean()

print(media_precios_Arroyomolinos_Madrid)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

import matplotlib.pyplot as plt

precios_Arroyomolinos_Madrid=ds[ds["level5"]=="Arroyomolinos (Madrid)"]["price"]

plt.hist(precios_Arroyomolinos_Madrid,edgecolor="pink")
plt.title("Histograma de precios de Arroyomolinos (Madrid)")
plt.xlabel("Precios de los inmuebles (USD)")
plt.ylabel("cantidad de inmuebles")
plt.grid(True)
plt.show()

# %% [markdown]
# *_ANÁLISIS BREVE:_*
#
# Según este histograma, los precios de los inmuebles en Arroyomolinos (Madrid), en su mayoría, rondan entre los 200.000 USD y los 400.000 USD.
#
# Además, se oberva que hay un pequeño grupo de inmuebles que tienen un precio muy bajo, cercano a 0. Lo cual sea, probablemente, debido al precio de mercado de zonas espcíficas, o porque son garajes, o plazas de estacionamiento.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

promedio_Valdemorillo=ds[ds["level5"]=="Valdemorillo"]["price"].mean()
promedio_Galapagar=ds[ds["level5"]=="Galapagar"]["price"].mean()

print("Promedio de Valdemorillo:", promedio_Valdemorillo)
print("Promedio de Galapagar:",promedio_Galapagar)
# Out:
# Promedio de Valdemorillo: 363860.2931034483
# Promedio de Galapagar: 360063.20238095237

# %% [markdown]
# _*CONCLUSIÓN:*_
#
# Los promedios de Valdemorillo y Galapagar no son iguales. En Valdemorillo son mayores los precios de los inmuebles.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

ds["pps"]=ds["price"]/ds["surface"]

pps_Valdemorillo=ds[ds["level5"]=="Valdemorillo"]["pps"].mean()
pps_Galapagar=ds[ds["level5"]=="Galapagar"]["pps"].mean()

print("Precio/m2 de Valdemorillo:",pps_Valdemorillo)
print("Precio/m2 de Galapagar:",pps_Galapagar)
# Out:
# Precio/m2 de Valdemorillo: 1317.9502109024986
# Precio/m2 de Galapagar: 1606.3240303094024

# %% [markdown]
# _CONCLUSIÓN:_
#
# Los precios por m2 en Galapagar son más costosos que en Valdemorillo, por un 17,95%.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

import matplotlib.pyplot as plt

plt.scatter(ds["price"],ds["surface"],color="red",marker="o",alpha=0.3)
plt.title("Diagrama de dispersión")
plt.xlabel("Precio (USD)")
plt.ylabel("Superficie (m2)")
plt.grid(True)
plt.show()

# %% [markdown]
# _CONCLUSIÓN:_
#
# Según el diagrama de dispersión, la mayoría de las viviendas tienen un precio elevado, con respecto su superficie.
#
# No se pueden apreciar correctamente los datos, debido a que, hay desviaciones demasiado alejadas en superficie.
#
# Se recomienda: Hacer una limpieza de datos para que estos datos alejados, no sesgen el análisis.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

cantidad_de_agencias=ds["realEstate_name"].nunique()

print(cantidad_de_agencias)
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

casas=ds["level5"].value_counts()
poblacion_con_mas_casas=casas.idxmax()
cantidad_de_casas=casas.max()

print("La población con mayor cantidad de casas es:",poblacion_con_mas_casas,"con",cantidad_de_casas)
# Out:
# La población con mayor cantidad de casas es:  Madrid Capital con 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

print(subconjunto_ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

mediana_precios=subconjunto_ds.groupby("level5")["price"].mean().reindex(poblaciones_cinturon_sur_Madrid)

import matplotlib.pyplot as plt

plt.bar(mediana_precios.index,mediana_precios.values)
plt.title("Mediana de precios en el Cinturón Sur de Madrid")
plt.xlabel("Población")
plt.ylabel("Precio medio (€)")
plt.grid(True)
plt.show()

# %% [markdown]
# _EXPLICACIÓN DE LO OBSERVADO:_
#
# Los precios más elevados son los de Getafe.
# Los precios más bajos son los de Fuenlabrada.
# La diferencia de precios entre Leganés y Alcorcón, son mínimos.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

variables_de_estudio=["price","rooms","surface","bathrooms"]

print("Cálculos:")

for calculos in variables_de_estudio:
    media_de_variables_de_estudio=subconjunto_ds[calculos].mean()
    varianza_de_variables_de_estudio=subconjunto_ds[calculos].var()
    
    print(calculos,"-> media:",media_de_variables_de_estudio,"varianza:",varianza_de_variables_de_estudio)
# Out:
# Cálculos:
# price -> media: 223094.48070562293 varianza: 14921367508.04902
# rooms -> media: 3.0177383592017737 varianza: 0.7188858892927542
# surface -> media: 111.75222363405337 varianza: 4263.051760316337
# bathrooms -> media: 1.633221850613155 varianza: 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

print("Casa más caras según población->")

for poblaciones in poblaciones_cinturon_sur_Madrid:
    casas_poblacion= subconjunto_ds[subconjunto_ds["level5"] == poblaciones]
    idx=casas_poblacion["price"].idxmax()
    direcciones=casas_poblacion.loc[idx,"address"]
    precios=casas_poblacion.loc[idx,"price"]
    
    print(f"{poblaciones}: {direcciones} - {precios} €")
# Out:
# Casa más caras según población->
# Fuenlabrada: Calle de Paulo Freire, 5, Fuenlabrada - 490000 €
# Leganés: Avenida Reina Sofía, Leganés - 650000 €
# Getafe: Getafe - 1050000 €
# Alcorcón: Alcorcón - 950000 €

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds = ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

subconjunto_ds["price_normalized"] = subconjunto_ds.groupby("level5")["price"].transform(
    lambda x: (x - x.min()) / (x.max() - x.min())         )

fig, axes = plt.subplots(2, 2, figsize=(12,9))

poblaciones_axes = {
"Fuenlabrada": axes[0,0],
"Leganés": axes[0,1],
"Getafe": axes[1, 0],
"Alcorcón": axes[1, 1]
}

for poblaciones, ax in poblaciones_axes.items():
    precios_normalizados = subconjunto_ds [subconjunto_ds["level5"] == poblaciones] ["price_normalized"]
    ax.hist(precios_normalizados, bins=30, alpha=1, edgecolor="black")
    ax.set_title("Histograma")
    ax.set_xlabel("Precio normalizado")
    ax.set_ylabel("Frecuencia")
    ax.legend()
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_596/1034979656.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto_ds["price_normalized"] = subconjunto_ds.groupby("level5")["price"].transform(
# /tmp/ipykernel_596/1034979656.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

subconjunto_ds.loc[:,"pps"]=subconjunto_ds["price"] / subconjunto_ds ["surface"]

pps_Getafe=subconjunto_ds[subconjunto_ds["level5"]=="Getafe"]["pps"].mean()
pps_Alcorcón=subconjunto_ds[subconjunto_ds["level5"]=="Alcorcón"]["pps"].mean()

print("Getafe:",pps_Getafe)

print("Alcorcón:",pps_Alcorcón)
# Out:
# Getafe: 2066.314949251463
# Alcorcón: 2239.302480199618
# /tmp/ipykernel_596/2985325216.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto_ds.loc[:,"pps"]=subconjunto_ds["price"] / subconjunto_ds ["surface"]

# %% [markdown]
# _OPINIONES:_
#
# Getafe tiene un precio/m2 un 7.72% más alto que Alcorcón. Habría que hacer un análisis del por qué.
#
# El precio por m2, es bastante accesible en comparción con otras zonas de Madrid.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
import pandas as pd
import matplotlib.pyplot as plt

ds = pd.read_csv('assets/real_estate.csv', sep=';')

poblaciones_cinturon_sur_Madrid=["Fuenlabrada","Leganés","Getafe","Alcorcón"]
subconjunto_ds=ds[ds["level5"].isin(poblaciones_cinturon_sur_Madrid)]

fig, axs =plt.subplots(2,2,figsize=(9,7))
axs=axs.flatten()

for i, poblacion in enumerate(poblaciones_cinturon_sur_Madrid):
    datos_para_graficar=subconjunto_ds[subconjunto_ds["level5"]==poblacion]
    axs[i].scatter(datos_para_graficar["surface"],datos_para_graficar["price"],alpha=0.3)
    axs[i].set_title(poblacion)
    axs[i].set_xlabel("Surface (m2)")
    axs[i].set_ylabel("Price")

plt.suptitle("Comparación de precios por m2 de cinturón sur de Madrid")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
from ipyleaflet import Map, basemaps, CircleMarker,Popup
from ipywidgets import HTML
mapa = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, basemap=basemaps.OpenStreetMap.Mapnik)
diccionario={
    "latitude":[40.1414,40.1942,40.1800,(40.2058,"N")],
    "longitude":[-3.4800,-3.4555,-3.4300,(-3.4942,"O")],
    "nombre_poblacion":["Fuenlabrada","Leganés","Getafe","Alcorcón"]
}
colores={
        "Fuenlabrada": "pink",
        "Leganés": "purple",
        "Getafe": "orange",
        "Alcorcón": "yellow"
        }
for lat, lon, poblacion in zip(diccionario["latitude"],diccionario["longitude"],diccionario["nombre_poblacion"]):
    marcador=CircleMarker(
        location=(lat, lon),
        radius=20,
        color=colores[poblacion],
        fill_color=colores[poblacion],
        fill_opacity=0.8
    )
    popup=Popup(
        location=(lat,lon),
        child=HTML(value=f"<b>{poblacion}</b>"),
        close_button=True,
        auto_close=False,
        close_on_scape_key=True
    )
    mapa.add_layer(marcador)
    mapa.add_layer(popup)
mapa
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
